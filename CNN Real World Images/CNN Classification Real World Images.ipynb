# %%
import os

# %%
data_dir = 'D:\\New folder\\TF2\\CNN\\cell_images'

# %%
os.listdir(data_dir)
# Out:
# ['test', 'train']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from matplotlib.image import imread

# %%
train_path = data_dir + '\\train\\'
test_path = data_dir + '\\test\\'

# %%
os.listdir(train_path)
# Out:
# ['parasitized', 'uninfected']

# %%
os.listdir(test_path)
# Out:
# ['parasitized', 'uninfected']

# %%
os.listdir(train_path + 'parasitized')[0]
# Out:
# 'C100P61ThinF_IMG_20150918_144104_cell_162.png'

# %%
para_cell = train_path + 'parasitized\\' + 'C100P61ThinF_IMG_20150918_144104_cell_162.png'

# %%
para_cell
# Out:
# 'D:\\New folder\\TF2\\CNN\\cell_images\\train\\parasitized\\C100P61ThinF_IMG_20150918_144104_cell_162.png'

# %%
plt.imshow(imread(para_cell))

# %%
os.listdir(train_path + 'uninfected')[0]
# Out:
# 'C100P61ThinF_IMG_20150918_144104_cell_128.png'

# %%
uninfected_cell = train_path + 'uninfected\\' + 'C100P61ThinF_IMG_20150918_144104_cell_128.png'

# %%
uninfected_cell
# Out:
# 'D:\\New folder\\TF2\\CNN\\cell_images\\train\\uninfected\\C100P61ThinF_IMG_20150918_144104_cell_128.png'

# %%
plt.imshow(imread(uninfected_cell))

# %%
len(os.listdir(train_path + 'parasitized'))
# Out:
# 12480

# %%
len(os.listdir(train_path + 'uninfected'))
# Out:
# 12480

# %%
len(os.listdir(test_path + 'parasitized'))
# Out:
# 1300

# %%
len(os.listdir(test_path + 'uninfected'))
# Out:
# 1300

# %%
dim1 = []
dim2 = []

for image_filename in os.listdir(test_path + 'uninfected'):
    img = imread(test_path + 'uninfected\\' + image_filename)
    d1, d2, colors = img.shape
    dim1.append(d1)
    dim2.append(d2)

# %%
dim1
# Out:
# [118,
#  172,
#  130,
#  163,
#  172,
#  139,
#  151,
#  160,
#  145,
#  127,
#  121,
#  154,
#  145,
#  127,
#  154,
#  151,
#  148,
#  130,
#  160,
#  136,
#  139,
#  190,
#  127,
#  133,
#  136,
#  124,
#  151,
#  151,
#  151,
#  160,
#  118,
#  154,
#  154,
#  121,
#  127,
#  118,
#  130,
#  124,
#  163,
#  88,
#  139,
#  127,
#  121,
#  139,
#  166,
#  133,
#  124,
#  154,
#  139,
#  127,
#  124,
#  136,
#  166,
#  133,
#  145,
#  157,
#  181,
#  148,
#  112,
#  124,
#  112,
#  106,
#  121,
#  148,
#  148,
#  112,
#  121,
#  148,
#  97,
#  112,
#  142,
#  118,
#  130,
#  151,
#  133,
#  136,
#  115,
#  145,
#  115,
#  142,
#  136,
#  130,
#  142,
#  124,
#  142,
#  136,
#  166,
#  148,
#  136,
#  142,
#  133,
#  130,
#  139,
#  124,
#  139,
#  121,
#  130,
#  142,
#  133,
#  118,
#  157,
#  127,
#  109,
#  112,
#  139,
#  142,
#  142,
#  112,
#  118,
#  100,
#  127,
#  145,
#  136,
#  160,
#  187,
#  130,
#  130,
#  157,
#  130,
#  130,
#  151,
#  175,
#  145,
#  136,
#  157,
#  133,
#  127,
#  154,
#  133,
#  151,
#  130,
#  136,
#  160,
#  130,
#  139,
#  145,
#  145,
#  145,
#  154,
#  133,
#  160,
#  142,
#  157,
#  145,
#  136,
#  121,
#  115,
#  121,
#  121,
#  127,
#  145,
#  130,
#  133,
#  142,
#  127,
#  121,
#  139,
#  118,
#  118,
#  148,
#  121,
#  145,
#  130,
#  169,
#  142,
#  136,
#  148,
#  142,
#  169,
#  115,
#  109,
#  166,
#  145,
#  127,
#  124,
#  124,
#  130,
#  196,
#  97,
#  115,
#  133,
#  139,
#  148,
#  109,
#  127,
#  175,
#  148,
#  136,
#  175,
#  151,
#  154,
#  133,
#  145,
#  115,
#  130,
#  121,
#  133,
#  142,
#  121,
#  136,
#  142,
#  136,
#  145,
#  127,
#  151,
#  136,
#  145,
#  166,
#  139,
#  151,
#  127,
#  136,
#  142,
#  118,
#  145,
#  127,
#  127,
#  118,
#  121,
#  121,
#  121,
#  106,
#  88,
#  136,
#  151,
#  133,
#  88,
#  142,
#  103,
#  124,
#  148,
#  151,
#  139,
#  157,
#  148,
#  154,
#  115,
#  115,
#  136,
#  133,
#  130,
#  136,
#  112,
#  115,
#  136,
#  109,
#  145,
#  133,
#  136,
#  112,
#  124,
#  115,
#  100,
#  118,
#  148,
#  118,
#  94,
#  145,
#  115,
#  136,
#  103,
#  172,
#  154,
#  151,
#  172,
#  124,
#  133,
#  181,
#  142,
#  136,
#  148,
#  136,
#  115,
#  103,
#  118,
#  121,
#  136,
#  130,
#  154,
#  115,
#  127,
#  130,
#  133,
#  130,
#  133,
#  136,
#  172,
#  157,
#  145,
#  133,
#  109,
#  154,
#  130,
#  142,
#  121,
#  118,
#  130,
#  127,
#  106,
#  133,
#  112,
#  118,
#  76,
#  118,
#  115,
#  163,
#  145,
#  154,
#  121,
#  127,
#  130,
#  148,
#  118,
#  115,
#  127,
#  121,
#  109,
#  118,
#  124,
#  145,
#  166,
#  142,
#  136,
#  130,
#  145,
#  142,
#  148,
#  106,
#  124,
#  106,
#  115,
#  115,
#  127,
#  124,
#  163,
#  139,
#  124,
#  106,
#  130,
#  106,
#  103,
#  121,
#  130,
#  127,
#  127,
#  121,
#  121,
#  127,
#  124,
#  136,
#  118,
#  127,
#  115,
#  124,
#  112,
#  115,
#  124,
#  121,
#  121,
#  133,
#  133,
#  103,
#  118,
#  124,
#  154,
#  109,
#  133,
#  145,
#  124,
#  115,
#  127,
#  115,
#  115,
#  103,
#  136,
#  118,
#  109,
#  124,
#  118,
#  127,
#  124,
#  124,
#  112,
#  115,
#  124,
#  109,
#  130,
#  112,
#  127,
#  121,
#  112,
#  142,
#  130,
#  127,
#  127,
#  130,
#  148,
#  100,
#  127,
#  118,
#  112,
#  112,
#  121,
#  118,
#  121,
#  121,
#  112,
#  121,
#  121,
#  100,
#  130,
#  127,
#  130,
#  127,
#  124,
#  127,
#  118,
#  106,
#  127,
#  103,
#  106,
#  109,
#  118,
#  151,
#  121,
#  100,
#  139,
#  118,
#  133,
#  127,
#  145,
#  127,
#  127,
#  106,
#  109,
#  97,
#  175,
#  118,
#  127,
#  145,
#  121,
#  136,
#  124,
#  175,
#  172,
#  172,
#  130,
#  130,
#  130,
#  127,
#  142,
#  121,
#  112,
#  145,
#  115,
#  133,
#  121,
#  109,
#  106,
#  136,
#  103,
#  130,
#  124,
#  124,
#  124,
#  130,
#  139,
#  145,
#  97,
#  133,
#  103,
#  115,
#  130,
#  106,
#  133,
#  124,
#  118,
#  118,
#  109,
#  124,
#  118,
#  160,
#  91,
#  118,
#  130,
#  112,
#  124,
#  190,
#  121,
#  115,
#  136,
#  175,
#  127,
#  130,
#  118,
#  109,
#  94,
#  157,
#  100,
#  106,
#  148,
#  130,
#  133,
#  109,
#  91,
#  97,
#  85,
#  97,
#  97,
#  118,
#  115,
#  130,
#  124,
#  109,
#  97,
#  109,
#  136,
#  166,
#  139,
#  130,
#  163,
#  136,
#  136,
#  94,
#  160,
#  118,
#  112,
#  124,
#  94,
#  100,
#  91,
#  88,
#  112,
#  130,
#  133,
#  112,
#  109,
#  112,
#  118,
#  154,
#  136,
#  142,
#  130,
#  148,
#  166,
#  121,
#  115,
#  115,
#  136,
#  130,
#  127,
#  124,
#  145,
#  139,
#  136,
#  136,
#  112,
#  142,
#  130,
#  112,
#  118,
#  133,
#  121,
#  118,
#  154,
#  133,
#  124,
#  124,
#  148,
#  97,
#  109,
#  106,
#  112,
#  127,
#  88,
#  103,
#  94,
#  124,
#  85,
#  142,
#  136,
#  142,
#  127,
#  115,
#  130,
#  124,
#  142,
#  124,
#  124,
#  124,
#  148,
#  136,
#  130,
#  148,
#  115,
#  124,
#  136,
#  118,
#  142,
#  127,
#  154,
#  121,
#  178,
#  127,
#  130,
#  136,
#  145,
#  133,
#  106,
#  169,
#  133,
#  154,
#  118,
#  106,
#  133,
#  130,
#  142,
#  130,
#  148,
#  133,
#  145,
#  121,
#  121,
#  133,
#  154,
#  163,
#  130,
#  151,
#  139,
#  124,
#  118,
#  136,
#  115,
#  145,
#  127,
#  124,
#  139,
#  160,
#  148,
#  121,
#  154,
#  127,
#  124,
#  145,
#  124,
#  127,
#  136,
#  124,
#  115,
#  118,
#  133,
#  118,
#  106,
#  127,
#  121,
#  130,
#  103,
#  130,
#  172,
#  136,
#  139,
#  130,
#  148,
#  145,
#  115,
#  130,
#  118,
#  148,
#  127,
#  142,
#  121,
#  136,
#  130,
#  118,
#  133,
#  127,
#  136,
#  145,
#  136,
#  136,
#  118,
#  136,
#  124,
#  127,
#  121,
#  151,
#  142,
#  133,
#  133,
#  139,
#  136,
#  148,
#  142,
#  142,
#  109,
#  124,
#  121,
#  121,
#  130,
#  142,
#  139,
#  148,
#  136,
#  139,
#  118,
#  145,
#  121,
#  130,
#  124,
#  121,
#  109,
#  130,
#  136,
#  148,
#  127,
#  130,
#  142,
#  178,
#  121,
#  127,
#  136,
#  151,
#  121,
#  115,
#  115,
#  148,
#  124,
#  112,
#  118,
#  130,
#  124,
#  136,
#  160,
#  133,
#  145,
#  133,
#  133,
#  133,
#  136,
#  136,
#  139,
#  136,
#  160,
#  124,
#  103,
#  124,
#  130,
#  112,
#  154,
#  139,
#  139,
#  124,
#  142,
#  121,
#  145,
#  124,
#  145,
#  142,
#  133,
#  118,
#  151,
#  142,
#  133,
#  154,
#  124,
#  163,
#  139,
#  178,
#  115,
#  136,
#  142,
#  142,
#  145,
#  154,
#  115,
#  118,
#  124,
#  121,
#  136,
#  127,
#  124,
#  127,
#  106,
#  121,
#  127,
#  136,
#  109,
#  112,
#  124,
#  103,
#  139,
#  115,
#  136,
#  106,
#  127,
#  121,
#  130,
#  136,
#  136,
#  124,
#  115,
#  124,
#  121,
#  136,
#  121,
#  142,
#  124,
#  133,
#  124,
#  130,
#  127,
#  109,
#  157,
#  133,
#  124,
#  130,
#  145,
#  127,
#  118,
#  130,
#  157,
#  142,
#  139,
#  124,
#  139,
#  139,
#  136,
#  160,
#  97,
#  139,
#  133,
#  136,
#  136,
#  139,
#  142,
#  127,
#  112,
#  118,
#  118,
#  115,
#  106,
#  97,
#  130,
#  115,
#  136,
#  127,
#  103,
#  106,
#  118,
#  136,
#  133,
#  115,
#  133,
#  124,
#  133,
#  133,
#  118,
#  157,
#  112,
#  142,
#  151,
#  154,
#  169,
#  136,
#  130,
#  142,
#  121,
#  121,
#  148,
#  136,
#  142,
#  127,
#  142,
#  127,
#  118,
#  148,
#  154,
#  154,
#  166,
#  118,
#  142,
#  154,
#  139,
#  124,
#  127,
#  145,
#  115,
#  109,
#  121,
#  106,
#  130,
#  106,
#  148,
#  139,
#  127,
#  112,
#  136,
#  142,
#  112,
#  133,
#  130,
#  112,
#  118,
#  121,
#  112,
#  136,
#  121,
#  127,
#  124,
#  124,
#  124,
#  124,
#  118,
#  130,
#  112,
#  115,
#  118,
#  154,
#  109,
#  112,
#  136,
#  121,
#  121,
#  139,
#  115,
#  133,
#  160,
#  127,
#  133,
#  142,
#  109,
#  139,
#  133,
#  121,
#  100,
#  130,
#  145,
#  130,
#  103,
#  118,
#  115,
#  94,
#  124,
#  133,
#  136,
#  121,
#  85,
#  121,
#  103,
#  139,
#  124,
#  61,
#  106,
#  121,
#  124,
#  127,
#  118,
#  130,
#  154,
#  142,
#  130,
#  124,
#  157,
#  124,
#  127,
#  133,
#  133,
#  130,
#  199,
#  127,
#  121,
#  127,
#  139,
#  121,
#  118,
#  124,
#  112,
#  160,
#  127,
#  139,
#  124,
#  118,
#  115,
#  127,
#  118,
#  115,
#  130,
#  160,
#  103,
#  151,
#  118,
#  109,
#  118,
#  103,
#  121,
#  130,
#  127,
#  121,
#  103,
#  130,
#  ...]

# %%
dim2
# Out:
# [118,
#  145,
#  151,
#  145,
#  139,
#  136,
#  160,
#  121,
#  142,
#  121,
#  100,
#  151,
#  139,
#  151,
#  112,
#  124,
#  145,
#  115,
#  166,
#  130,
#  133,
#  130,
#  136,
#  136,
#  124,
#  115,
#  142,
#  190,
#  151,
#  163,
#  112,
#  142,
#  151,
#  127,
#  142,
#  172,
#  151,
#  127,
#  154,
#  91,
#  124,
#  139,
#  124,
#  127,
#  148,
#  118,
#  148,
#  157,
#  139,
#  145,
#  154,
#  163,
#  148,
#  130,
#  160,
#  136,
#  121,
#  169,
#  145,
#  115,
#  106,
#  124,
#  130,
#  112,
#  124,
#  106,
#  112,
#  121,
#  100,
#  115,
#  136,
#  118,
#  127,
#  148,
#  130,
#  118,
#  124,
#  139,
#  133,
#  118,
#  121,
#  127,
#  136,
#  127,
#  124,
#  124,
#  136,
#  130,
#  130,
#  112,
#  127,
#  136,
#  130,
#  124,
#  130,
#  109,
#  169,
#  124,
#  142,
#  127,
#  106,
#  130,
#  97,
#  100,
#  145,
#  106,
#  148,
#  136,
#  136,
#  133,
#  121,
#  133,
#  136,
#  157,
#  133,
#  139,
#  127,
#  139,
#  151,
#  157,
#  148,
#  163,
#  145,
#  136,
#  127,
#  130,
#  160,
#  133,
#  130,
#  121,
#  136,
#  145,
#  121,
#  142,
#  148,
#  148,
#  127,
#  139,
#  148,
#  148,
#  151,
#  160,
#  154,
#  145,
#  139,
#  127,
#  121,
#  106,
#  106,
#  145,
#  112,
#  130,
#  124,
#  139,
#  145,
#  142,
#  151,
#  130,
#  118,
#  133,
#  154,
#  136,
#  139,
#  121,
#  142,
#  148,
#  136,
#  172,
#  124,
#  205,
#  175,
#  118,
#  127,
#  130,
#  124,
#  112,
#  142,
#  142,
#  106,
#  127,
#  118,
#  139,
#  139,
#  124,
#  121,
#  151,
#  139,
#  130,
#  124,
#  136,
#  151,
#  115,
#  130,
#  130,
#  121,
#  130,
#  106,
#  121,
#  145,
#  121,
#  151,
#  133,
#  139,
#  157,
#  145,
#  127,
#  166,
#  154,
#  133,
#  163,
#  127,
#  157,
#  127,
#  133,
#  166,
#  133,
#  127,
#  121,
#  136,
#  127,
#  118,
#  109,
#  94,
#  136,
#  139,
#  121,
#  115,
#  145,
#  94,
#  151,
#  148,
#  160,
#  139,
#  157,
#  139,
#  142,
#  106,
#  133,
#  136,
#  142,
#  151,
#  142,
#  175,
#  100,
#  127,
#  142,
#  124,
#  145,
#  145,
#  112,
#  130,
#  124,
#  106,
#  130,
#  121,
#  127,
#  100,
#  148,
#  115,
#  121,
#  115,
#  106,
#  127,
#  145,
#  160,
#  133,
#  142,
#  160,
#  115,
#  121,
#  133,
#  115,
#  112,
#  133,
#  112,
#  130,
#  130,
#  181,
#  118,
#  121,
#  139,
#  133,
#  115,
#  124,
#  133,
#  136,
#  133,
#  136,
#  136,
#  124,
#  121,
#  151,
#  145,
#  127,
#  106,
#  130,
#  145,
#  121,
#  112,
#  121,
#  103,
#  121,
#  109,
#  115,
#  118,
#  151,
#  139,
#  136,
#  148,
#  112,
#  127,
#  124,
#  112,
#  112,
#  130,
#  124,
#  115,
#  127,
#  118,
#  145,
#  130,
#  163,
#  133,
#  160,
#  148,
#  139,
#  142,
#  100,
#  133,
#  118,
#  130,
#  94,
#  133,
#  169,
#  118,
#  157,
#  124,
#  133,
#  148,
#  118,
#  115,
#  130,
#  133,
#  130,
#  133,
#  127,
#  130,
#  130,
#  118,
#  124,
#  118,
#  112,
#  145,
#  115,
#  118,
#  121,
#  121,
#  145,
#  121,
#  145,
#  130,
#  103,
#  112,
#  124,
#  106,
#  121,
#  118,
#  166,
#  118,
#  151,
#  112,
#  136,
#  124,
#  115,
#  130,
#  124,
#  121,
#  133,
#  100,
#  121,
#  118,
#  109,
#  112,
#  115,
#  121,
#  118,
#  118,
#  130,
#  115,
#  127,
#  121,
#  121,
#  166,
#  121,
#  124,
#  133,
#  142,
#  115,
#  130,
#  115,
#  103,
#  127,
#  118,
#  112,
#  118,
#  130,
#  121,
#  127,
#  142,
#  112,
#  139,
#  151,
#  133,
#  136,
#  133,
#  136,
#  118,
#  106,
#  127,
#  106,
#  109,
#  109,
#  139,
#  106,
#  94,
#  85,
#  97,
#  133,
#  109,
#  118,
#  121,
#  112,
#  121,
#  106,
#  112,
#  118,
#  157,
#  151,
#  127,
#  139,
#  136,
#  127,
#  133,
#  193,
#  217,
#  136,
#  136,
#  139,
#  142,
#  124,
#  115,
#  115,
#  124,
#  106,
#  118,
#  133,
#  118,
#  100,
#  103,
#  103,
#  109,
#  112,
#  124,
#  115,
#  139,
#  112,
#  124,
#  127,
#  109,
#  139,
#  100,
#  109,
#  103,
#  115,
#  112,
#  118,
#  127,
#  118,
#  130,
#  130,
#  130,
#  127,
#  130,
#  127,
#  115,
#  130,
#  127,
#  151,
#  145,
#  121,
#  163,
#  139,
#  133,
#  112,
#  115,
#  109,
#  112,
#  118,
#  100,
#  103,
#  172,
#  139,
#  133,
#  127,
#  106,
#  97,
#  94,
#  82,
#  106,
#  127,
#  109,
#  133,
#  118,
#  106,
#  91,
#  121,
#  148,
#  133,
#  151,
#  109,
#  178,
#  154,
#  145,
#  94,
#  97,
#  115,
#  124,
#  100,
#  70,
#  103,
#  109,
#  121,
#  130,
#  136,
#  142,
#  112,
#  118,
#  103,
#  133,
#  151,
#  172,
#  118,
#  133,
#  142,
#  154,
#  118,
#  103,
#  112,
#  139,
#  139,
#  124,
#  127,
#  136,
#  139,
#  121,
#  136,
#  163,
#  142,
#  130,
#  112,
#  109,
#  103,
#  115,
#  112,
#  190,
#  121,
#  124,
#  130,
#  112,
#  100,
#  100,
#  109,
#  106,
#  130,
#  109,
#  124,
#  124,
#  115,
#  79,
#  148,
#  157,
#  121,
#  160,
#  118,
#  124,
#  115,
#  130,
#  166,
#  133,
#  127,
#  103,
#  142,
#  142,
#  127,
#  121,
#  139,
#  148,
#  118,
#  130,
#  145,
#  130,
#  175,
#  127,
#  139,
#  166,
#  136,
#  139,
#  157,
#  115,
#  127,
#  127,
#  124,
#  145,
#  124,
#  124,
#  124,
#  142,
#  142,
#  133,
#  133,
#  142,
#  142,
#  136,
#  133,
#  169,
#  124,
#  130,
#  127,
#  136,
#  115,
#  118,
#  127,
#  106,
#  148,
#  136,
#  139,
#  136,
#  184,
#  142,
#  136,
#  121,
#  133,
#  118,
#  148,
#  121,
#  133,
#  127,
#  133,
#  88,
#  130,
#  124,
#  118,
#  112,
#  136,
#  124,
#  148,
#  106,
#  151,
#  148,
#  145,
#  133,
#  124,
#  124,
#  130,
#  121,
#  139,
#  121,
#  142,
#  118,
#  124,
#  115,
#  133,
#  124,
#  121,
#  115,
#  142,
#  136,
#  136,
#  154,
#  154,
#  127,
#  139,
#  148,
#  139,
#  160,
#  148,
#  145,
#  148,
#  112,
#  148,
#  136,
#  124,
#  133,
#  142,
#  145,
#  136,
#  118,
#  184,
#  124,
#  121,
#  136,
#  142,
#  145,
#  139,
#  145,
#  124,
#  124,
#  142,
#  133,
#  127,
#  121,
#  136,
#  139,
#  145,
#  115,
#  133,
#  139,
#  118,
#  112,
#  133,
#  133,
#  142,
#  121,
#  124,
#  154,
#  145,
#  121,
#  145,
#  145,
#  121,
#  127,
#  121,
#  133,
#  124,
#  139,
#  118,
#  121,
#  136,
#  139,
#  136,
#  139,
#  145,
#  127,
#  121,
#  106,
#  148,
#  115,
#  142,
#  112,
#  139,
#  142,
#  145,
#  130,
#  136,
#  145,
#  127,
#  139,
#  145,
#  127,
#  112,
#  106,
#  157,
#  139,
#  130,
#  127,
#  136,
#  142,
#  133,
#  118,
#  118,
#  145,
#  145,
#  136,
#  115,
#  118,
#  133,
#  133,
#  124,
#  139,
#  136,
#  115,
#  124,
#  118,
#  139,
#  115,
#  130,
#  124,
#  121,
#  118,
#  139,
#  130,
#  118,
#  121,
#  133,
#  121,
#  124,
#  133,
#  145,
#  127,
#  121,
#  130,
#  124,
#  133,
#  139,
#  124,
#  130,
#  130,
#  121,
#  130,
#  133,
#  124,
#  112,
#  115,
#  106,
#  124,
#  133,
#  121,
#  124,
#  112,
#  127,
#  127,
#  136,
#  136,
#  124,
#  154,
#  139,
#  136,
#  151,
#  103,
#  139,
#  130,
#  127,
#  127,
#  130,
#  124,
#  118,
#  106,
#  130,
#  118,
#  112,
#  112,
#  130,
#  130,
#  127,
#  121,
#  118,
#  124,
#  100,
#  130,
#  106,
#  139,
#  127,
#  136,
#  106,
#  118,
#  136,
#  118,
#  124,
#  109,
#  130,
#  157,
#  151,
#  163,
#  130,
#  130,
#  133,
#  160,
#  190,
#  127,
#  124,
#  133,
#  148,
#  127,
#  139,
#  145,
#  160,
#  121,
#  133,
#  154,
#  124,
#  127,
#  115,
#  133,
#  151,
#  139,
#  142,
#  127,
#  136,
#  151,
#  154,
#  130,
#  142,
#  190,
#  148,
#  127,
#  124,
#  163,
#  130,
#  124,
#  118,
#  133,
#  124,
#  106,
#  127,
#  145,
#  118,
#  178,
#  145,
#  142,
#  124,
#  106,
#  142,
#  109,
#  130,
#  121,
#  148,
#  106,
#  100,
#  118,
#  124,
#  145,
#  172,
#  133,
#  139,
#  118,
#  121,
#  133,
#  127,
#  121,
#  124,
#  136,
#  127,
#  139,
#  124,
#  109,
#  127,
#  139,
#  133,
#  118,
#  112,
#  109,
#  103,
#  136,
#  139,
#  154,
#  124,
#  73,
#  130,
#  100,
#  115,
#  112,
#  79,
#  112,
#  118,
#  124,
#  133,
#  136,
#  133,
#  136,
#  106,
#  130,
#  136,
#  142,
#  148,
#  124,
#  139,
#  124,
#  151,
#  139,
#  118,
#  127,
#  127,
#  148,
#  127,
#  121,
#  124,
#  136,
#  151,
#  124,
#  187,
#  115,
#  121,
#  115,
#  118,
#  130,
#  121,
#  136,
#  160,
#  127,
#  136,
#  124,
#  112,
#  121,
#  97,
#  109,
#  139,
#  118,
#  127,
#  103,
#  127,
#  ...]

# %%
sns.jointplot(dim1, dim2)
# Out:
# C:\Users\91773\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
np.mean(dim1)
# Out:
# 130.92538461538462

# %%
np.mean(dim2)
# Out:
# 130.75

# %%
image_shape = (130, 130, 3)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
image_gen = ImageDataGenerator(rotation_range = 20, 
                               width_shift_range = 0.1, 
                               height_shift_range = 0.1, 
                               shear_range = 0.1, 
                               zoom_range = 0.1, 
                               horizontal_flip = True, 
                               fill_mode = 'nearest')

# %%
para_img = imread(para_cell)
plt.imshow(image_gen.random_transform(para_img))

# %%
image_gen.flow_from_directory(train_path)
# Out:
# Found 24958 images belonging to 2 classes.

# %%
image_gen.flow_from_directory(test_path)
# Out:
# Found 2600 images belonging to 2 classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Dropout, Flatten

# %%
model = Sequential()

model.add(Conv2D(filters = 32, kernel_size = (3, 3), input_shape = image_shape, activation = 'relu'))
model.add(MaxPool2D(pool_size = (2, 2)))

model.add(Conv2D(filters = 64, kernel_size = (3, 3), input_shape = image_shape, activation = 'relu'))
model.add(MaxPool2D(pool_size = (2, 2)))

model.add(Conv2D(filters = 64, kernel_size = (3, 3), input_shape = image_shape, activation = 'relu'))
model.add(MaxPool2D(pool_size = (2, 2)))

model.add(Flatten())

model.add(Dense(128, activation = 'relu'))
model.add(Dropout(0.5))

model.add(Dense(1, activation = 'sigmoid'))

model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 62, 62, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 31, 31, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 29, 29, 64)        36928
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 12544)             0
#
#  dense (Dense)               (None, 128)               1605760
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 1,662,209
# Trainable params: 1,662,209
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
early_stop = EarlyStopping(monitor = 'val_loss', patience = 2)

# %%
batch_size = 16

# %%
train_image_gen = image_gen.flow_from_directory(train_path, 
                                                target_size = image_shape[:2], 
                                                color_mode = 'rgb', 
                                                batch_size = batch_size, 
                                                class_mode = 'binary')
# Out:
# Found 24958 images belonging to 2 classes.

# %%
test_image_gen = image_gen.flow_from_directory(test_path, 
                                                target_size = image_shape[:2], 
                                                color_mode = 'rgb', 
                                                batch_size = batch_size, 
                                                class_mode = 'binary', 
                                                shuffle = False)
# Out:
# Found 2600 images belonging to 2 classes.

# %%
train_image_gen.class_indices
# Out:
# {'parasitized': 0, 'uninfected': 1}

# %%
# %%time
results = model.fit_generator(train_image_gen, epochs = 20, validation_data = test_image_gen, callbacks = [early_stop])
# Out:
# Epoch 1/20
# <timed exec>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# 1560/1560 [==============================] - 91s 55ms/step - loss: 1.0487 - accuracy: 0.5452 - val_loss: 0.6767 - val_accuracy: 0.5885
# Epoch 2/20
# 1560/1560 [==============================] - 78s 50ms/step - loss: 0.6761 - accuracy: 0.5854 - val_loss: 0.6774 - val_accuracy: 0.5738
# Epoch 3/20
# 1560/1560 [==============================] - 77s 49ms/step - loss: 0.6690 - accuracy: 0.5979 - val_loss: 0.6628 - val_accuracy: 0.6046
# Epoch 4/20
# 1560/1560 [==============================] - 76s 49ms/step - loss: 0.6716 - accuracy: 0.5935 - val_loss: 0.6579 - val_accuracy: 0.6250
# Epoch 5/20
# 1560/1560 [==============================] - 78s 50ms/step - loss: 0.6661 - accuracy: 0.6067 - val_loss: 0.6597 - val_accuracy: 0.6158
# Epoch 6/20
# 1560/1560 [==============================] - 76s 49ms/step - loss: 0.6723 - accuracy: 0.6046 - val_loss: 0.6578 - val_accuracy: 0.6142
# Epoch 7/20
# 1560/1560 [==============================] - 76s 49ms/step - loss: 0.6575 - accuracy: 0.6202 - val_loss: 0.5340 - val_accuracy: 0.7308
# Epoch 8/20
# 1560/1560 [==============================] - 77s 50ms/step - loss: 0.3911 - accuracy: 0.8484 - val_loss: 0.2410 - val_accuracy: 0.9265
# Epoch 9/20
# 1560/1560 [==============================] - 77s 49ms/step - loss: 0.2135 - accuracy: 0.9357 - val_loss: 0.1912 - val_accuracy: 0.9354
# Epoch 10/20
# 1560/1560 [==============================] - 77s 49ms/step - loss: 0.1965 - accuracy: 0.9407 - val_loss: 0.2123 - val_accuracy: 0.9265
# Epoch 11/20
# 1560/1560 [==============================] - 77s 49ms/step - loss: 0.1914 - accuracy: 0.9422 - val_loss: 0.1705 - val_accuracy: 0.9438
# Epoch 12/20
# 1560/1560 [==============================] - 78s 50ms/step - loss: 0.1793 - accuracy: 0.9447 - val_loss: 0.1847 - val_accuracy: 0.9431
# Epoch 13/20
# 1560/1560 [==============================] - 76s 49ms/step - loss: 0.1802 - accuracy: 0.9437 - val_loss: 0.1797 - val_accuracy: 0.9423
# CPU times: total: 23min 9s
# Wall time: 16min 55s

# %%
model.save('malaria_detector.h5')

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses.plot()
# Out:
# <AxesSubplot:>

# %%
model.evaluate_generator(test_image_gen)
# Out:
# C:\Users\91773\AppData\Local\Temp\ipykernel_17236\4011314882.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   model.evaluate_generator(test_image_gen)
# [0.1806759238243103, 0.943461537361145]

# %%
pred = model.predict_generator(test_image_gen)
# Out:
# C:\Users\91773\AppData\Local\Temp\ipykernel_17236\2032896581.py:1: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   pred = model.predict_generator(test_image_gen)

# %%
predictions = pred > 0.5

# %%
len(pred)
# Out:
# 2600

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
test_image_gen.classes
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
print(classification_report(test_image_gen.classes, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.92      0.94      1300
#            1       0.92      0.97      0.94      1300
#
#     accuracy                           0.94      2600
#    macro avg       0.94      0.94      0.94      2600
# weighted avg       0.94      0.94      0.94      2600

# %%
print(confusion_matrix(test_image_gen.classes, predictions))
# Out:
# [[1191  109]
#  [  40 1260]]

# %%
from tensorflow.keras.preprocessing import image

# %%
my_image = image.load_img(para_cell, target_size = image_shape)

# %%
my_image
# Out:
# <PIL.Image.Image image mode=RGB size=130x130 at 0x20FF565FAF0>

# %%
my_image_array = image.img_to_array(my_image)

# %%
my_image_array.shape
# Out:
# (130, 130, 3)

# %%
my_image_array = np.expand_dims(my_image_array, axis = 0)

# %%
my_image_array.shape
# Out:
# (1, 130, 130, 3)

# %%
model.predict(my_image_array)
# Out:
# array([[0.00026585]], dtype=float32)

# %%
train_image_gen.class_indices
# Out:
# {'parasitized': 0, 'uninfected': 1}
